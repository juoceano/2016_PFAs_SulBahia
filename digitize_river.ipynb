# %%
import pandas as pd


itanhentinga = pd.read_csv('ItanhentingaRiver.csv')
itanhentinga
# Out:
#           Lat        Lon
# 0  -17.533709 -39.225754
# 1  -17.527213 -39.229783
# 2  -17.520954 -39.229409
# 3  -17.517230 -39.227332
# 4  -17.514699 -39.226664
# 5  -17.511565 -39.225795
# 6  -17.492153 -39.230282
# 7  -17.486349 -39.230063
# 8  -17.477825 -39.227778
# 9  -17.472727 -39.228186
# 10 -17.467511 -39.231858
# 11 -17.463307 -39.238224
# 12 -17.461011 -39.239407
# 13 -17.457274 -39.249771
# 14 -17.455678 -39.260014
# 15 -17.455756 -39.265441
# 16 -17.459026 -39.275846
# 17 -17.455912 -39.285231
# 18 -17.448710 -39.292045
# 19 -17.445129 -39.298003
# 20 -17.443066 -39.311917

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


plt.plot(itanhentinga['Lon'], itanhentinga['Lat'], 'b-');

# %% [markdown]
# ```js
# var Esri_WorldStreetMap = L.tileLayer('https://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{z}/{y}/{x}', {
# 	attribution: 'Tiles &copy; Esri &mdash; Source: Esri, DeLorme, NAVTEQ, USGS, Intermap, iPC, NRCAN, Esri Japan, METI, Esri China (Hong Kong), Esri (Thailand), TomTom, 2012'
# });
# ```
